# %% [markdown]
# # Worksheet 02
#
# Name: William Huang - Collaborations: None
# UID: U53888747
#
# GitHub Repo Link (Branch worksheet_02): https://github.com/will18870/Data-Science-Fundamentals/tree/worksheet-02
#
# ### Topics
#
# - Effective Programming
#
# ### Effective Programming
#
# a) What is a drawback of the top down approach?

# %% [markdown]
# One drawback of the top-down approach is that projects can be delayed or spiral out of control if resources/time-spent for plans are estimated incorrectly. Say you have to design a system, and you know the high-level specifications of it. If the time it takes to implement a core, dependent lower-level piece of the project is underestimated, it could cause a bottleneck in the project timeline.
# Additionally, changes in project specifications mid-development can heavily affect projects done from the top-down, since core functions for the old specifications have already been planned/abstracted/coded.

# %% [markdown]
# b) What is a drawback of the bottom up approach?

# %% [markdown]
# One drawback of the bottom-up approach is that there is no working project until the end of the development cycle. This means it can be difficult to determine missing functions / what parts of the project have been finished. This also makes general testing of the project's functionalities difficult until all of the parts of the project are finished.

# %% [markdown]
# c) What are 3 things you can do to have a better debugging experience?

# %% [markdown]
# - You can mentally trace and run through your code to see if any of your logic fails during a run.
# - You can look outside your code / things outside your control; maybe your modules/libraries are at fault, or the API isn't communicating with your code properly.
# - You can take a break! I remember coding until like 5am for CS350 because I was stumped on something, and then figuring it out the next day after sleeping on it.

# %% [markdown]
# d) (Optional) Follow along with the live coding. You can write your code here:

# %%
# N/A :(

# %% [markdown]
# ## Exercise
#
# This exercise will use the [Titanic dataset](https://www.kaggle.com/c/titanic/data) (https://www.kaggle.com/c/titanic/data). Download the file named `train.csv` and place it in the same folder as this notebook.
#
# The goal of this exercise is to practice using [pandas](https://pypi.org/project/pandas/) methods. If your:
#
# 1. code is taking a long time to run
# 2. code involves for loops or while loops
# 3. code spans multiple lines
#
# look through the pandas documentation for alternatives. This [cheat sheet](https://pandas.pydata.org/Pandas_Cheat_Sheet.pdf) may come in handy.
#
# a) Complete the code below to read in a filepath to the `train.csv` and returns the DataFrame.

# %%
import pandas as pd

df = pd.read_csv("train.csv")
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# b) Complete the code so it returns the number of rows that have at least one empty column value

# %%
print("there are " +  str(df.isnull().any(axis=1).sum()) + " rows with at least one empty value")
# Out:
# there are 708 rows with at least one empty value

# %% [markdown]
# c) Complete the code below to remove all columns with more than 200 NaN values

# %%
df = df.dropna(axis=1, thresh=len(df.index)-200)
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Embarked'],
#       dtype='object')

# %% [markdown]
# d) Complete the code below to replaces `male` with 0 and `female` with 1

# %%
df['Sex'] = df['Sex'].replace({'male': 0, 'female': 1})
df.head()
# Out:
# C:\Users\will1\AppData\Local\Temp\ipykernel_37784\48985843.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Sex'] = df['Sex'].replace({'male': 0, 'female': 1})
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0      1      0
# 2                             Heikkinen, Miss. Laina    1  26.0      0      0
# ...

# %% [markdown]
# e) Complete the code below to add four columns `First Name`, `Middle Name`, `Last Name`, and `Title` corresponding to the value in the `name` column.
#
# For example: `Braund, Mr. Owen Harris` would be:
#
# |First Name | Middle Name | Last Name | Title |
# |-----------|-------------|-----------|-------|
# | Owen      |  Harris     |  Braund   | Mr    |
#
# Anything not clearly one of the above 4 categories can be ignored.

# %%
df[['First Name', 'Middle Name', 'Last Name', 'Title']] = df['Name'].str.split(' ', n=3, expand=True)[[2, 3, 0, 1]].apply(lambda row: row.str.replace(',', '')) # last bit is just to remove the comma in last name
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0      1      0
# 2                             Heikkinen, Miss. Laina    1  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.0      1      0
# 4                           Allen, Mr. William Henry    0  35.0      0      0
#
#              Ticket     Fare Embarked First Name  \
# 0         A/5 21171   7.2500        S       Owen
# 1          PC 17599  71.2833        C       John
# 2  STON/O2. 3101282   7.9250        S      Laina
# 3            113803  53.1000        S    Jacques
# ...

# %% [markdown]
# f) Complete the code below to replace all missing ages with the average age

# %%
df['Age'] = df['Age'].fillna(df['Age'].mean())
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0      1      0
# 2                             Heikkinen, Miss. Laina    1  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.0      1      0
# 4                           Allen, Mr. William Henry    0  35.0      0      0
#
#              Ticket     Fare Embarked First Name  \
# 0         A/5 21171   7.2500        S       Owen
# 1          PC 17599  71.2833        C       John
# 2  STON/O2. 3101282   7.9250        S      Laina
# 3            113803  53.1000        S    Jacques
# ...

# %% [markdown]
# g) Plot a bar chart of the average age of those that survived and did not survive. Briefly comment on what you observe.

# %%
import matplotlib.pyplot as plt

plt.bar([0,1], df.groupby('Survived')['Age'].mean())

# My Observation: It seems like age did not play a meaningful factor in whether or not a passenger survived the tragedy or not. While yes, the average age of the survivors
# were on average 2 years younger, the difference is not big enough to be significant. I would actually suspect gender to have a more significant difference, as I remember
# hearing that the crew offered lifeboats to women and children first.
# Out:
# <BarContainer object of 2 artists>
