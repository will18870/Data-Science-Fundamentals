# %% [markdown]
# # Worksheet 18
#
# Name: William Huang\
# UID: U53888747\
# GitHub Repo Link (Branch worksheet_18): https://github.com/will18870/Data-Science-Fundamentals/tree/worksheet_18
#
# ### Topics
#
# - Linear Regression
#
# ### Optional Challenge
#
# Every day my alarm goes off at seemingly random times… I’ve recorded the times at which it goes off for the past year of so (1 - 355 days). Today is day 356. Can you predict when my alarm will ring using `data.csv`?
#
# Please fill out the piazza poll if you think you found the answer.
#
# ## Linear Regression
#
# Where does randomness come from?

# %%
# %matplotlib widget
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

SAMPLE_SIZE = 100

# it's possible for y = 3 * x_1 + (1/4) * x_2
# but we don't know to look for x_2 and we only have x_1 as a feature
x1 = -10.0 + 20.0 * np.random.random(SAMPLE_SIZE)
x2 = -10.0 + 20.0 * np.random.random(SAMPLE_SIZE)
y = 3 * x1 + (1/4) * x2

# Create the figure
fig = plt.figure()

# Add an axes
ax = fig.add_subplot(111,projection='3d')

# and plot the point 
ax.scatter(x1 , x2 , y,  color='green')
ax.set_xlabel("x1")
ax.set_ylabel("x2")
ax.set_zlabel("y")
plt.show()

# this is a recurring issue with my matplotlib installation -- working on fixing it soon hopefully!
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [1], line 15
#      12 y = 3 * x1 + (1/4) * x2
#      14 # Create the figure
# ---> 15 fig = plt.figure()
#      17 # Add an axes
#      18 ax = fig.add_subplot(111,projection='3d')
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib\pyplot.py:934, in figure(num, figsize, dpi, facecolor, edgecolor, frameon, FigureClass, clear, **kwargs)
#     924 if len(allnums) == max_open_warning >= 1:
#     925     _api.warn_external(
#     926         f"More than {max_open_warning} figures have been opened. "
#     927         f"Figures created through the pyplot interface "
#    (...)
#     931         f"Consider using `matplotlib.pyplot.close()`.",
#     932         RuntimeWarning)
# --> 934 manager = new_figure_manager(
#     935     num, figsize=figsize, dpi=dpi,
#     936     facecolor=facecolor, edgecolor=edgecolor, frameon=frameon,
#     937     FigureClass=FigureClass, **kwargs)
#     938 fig = manager.canvas.figure
#     939 if fig_label:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib\pyplot.py:465, in new_figure_manager(*args, **kwargs)
#     463 """Create a new figure manager instance."""
#     464 _warn_if_gui_out_of_main_thread()
# --> 465 return _get_backend_mod().new_figure_manager(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib\backend_bases.py:3396, in _Backend.new_figure_manager(cls, num, *args, **kwargs)
#    3394 fig_cls = kwargs.pop('FigureClass', Figure)
#    3395 fig = fig_cls(*args, **kwargs)
# -> 3396 return cls.new_figure_manager_given_figure(num, fig)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\ipympl\backend_nbagg.py:487, in _Backend_ipympl.new_figure_manager_given_figure(num, figure)
#     485 if 'nbagg.transparent' in rcParams and rcParams['nbagg.transparent']:
#     486     figure.patch.set_alpha(0)
# --> 487 manager = FigureManager(canvas, num)
#     489 if is_interactive():
#     490     _Backend_ipympl._to_show.append(figure)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\ipympl\backend_nbagg.py:461, in FigureManager.__init__(self, canvas, num)
#     459 FigureManagerWebAgg.__init__(self, canvas, num)
#     460 self.web_sockets = [self.canvas]
# --> 461 self.toolbar = Toolbar(self.canvas)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\ipympl\backend_nbagg.py:122, in Toolbar.__init__(self, canvas, *args, **kwargs)
#     120 def __init__(self, canvas, *args, **kwargs):
#     121     DOMWidget.__init__(self, *args, **kwargs)
# --> 122     NavigationToolbar2WebAgg.__init__(self, canvas, *args, **kwargs)
#     124     self.on_msg(self.canvas._handle_message)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib\backends\backend_webagg_core.py:392, in NavigationToolbar2WebAgg.__init__(self, canvas)
#     390 def __init__(self, canvas):
#     391     self.message = ''
# --> 392     super().__init__(canvas)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib\backend_bases.py:2844, in NavigationToolbar2.__init__(self, canvas)
#    2842 self.canvas = canvas
#    2843 canvas.toolbar = self
# -> 2844 self._nav_stack = cbook._Stack()
#    2845 # This cursor will be set after the initial draw.
#    2846 self._last_cursor = tools.Cursors.POINTER
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib\_api\__init__.py:217, in caching_module_getattr.<locals>.__getattr__(name)
#     215 if name in props:
#     216     return props[name].__get__(instance)
# --> 217 raise AttributeError(
#     218     f"module {cls.__module__!r} has no attribute {name!r}")
#
# AttributeError: module 'matplotlib.cbook' has no attribute '_Stack'

# %% [markdown]
# a) Create and plot a dataset of 100 (Y, X) points where `Y = 1 + 0.5 * X + eps`.

# %%
import numpy as np
import matplotlib.pyplot as plt

SAMPLE_SIZE = 100

fig = plt.figure()
ax = fig.subplots()

true_beta = np.array([ 1 , 0.5 ])
x = -10.0 + 20.0 * np.random.random(SAMPLE_SIZE)
y = true_beta[0] + true_beta[1] * x + np.random.randn(SAMPLE_SIZE)
x_plot = np.linspace(-10,10,50)
plt.plot(x_plot, true_beta[0] + true_beta[1] * x_plot, lw=2, c='g', label='Truth')
plt.plot(x,y,'ro',markersize=4)
ax.set_xlim(-10, 10)
ax.set_ylim(-10, 10)
plt.show()

# %% [markdown]
# b) Plot the least squares estimate line through the scatter plot.

# %%
intercept = np.ones(np.shape(x)[0])
X = np.array([intercept, x]).T
beta_hat = np.linalg.inv(X.T @ X) @ X.T @ y

x_plot = np.linspace(-10,10,50)
y_est = beta_hat[0] + beta_hat[1] * x_plot
plt.plot(x_plot, y_est,'b--', lw=2, label='Estimate')
plt.plot(x_plot, true_beta[0] + true_beta[1] * x_plot, lw=2, c='g', label='Truth')
plt.plot(x, y,'ro',markersize=4)
plt.legend()
plt.show()

# %% [markdown]
# c) How does the estimate of `beta` compare to the parameters we used to generate the data?

# %%
print(beta_hat)
print(true_beta)

# intercept and slope are similar!
# Out:
# [1.04704574 0.51673158]
# [1.  0.5]

# %% [markdown]
# d) Create and plot a dataset of 100 (Y, X) points where `Y = 1 + 3 * X + .5 * X^2 + eps`.

# %%
import numpy as np
import matplotlib.pyplot as plt

SAMPLE_SIZE = 100

fig = plt.figure()
ax = fig.subplots()

true_beta = np.array([ 1 , 3, 0.5 ])
x = -10.0 + 20.0 * np.random.random(SAMPLE_SIZE)
y = true_beta[0] + true_beta[1] * x + true_beta[2] * (x**2) + np.random.randn(SAMPLE_SIZE)
x_plot = np.linspace(-10,10,50)
plt.plot(x_plot, true_beta[0] + true_beta[1] * x_plot + true_beta[2] * x_plot**2, lw=2, c='g', label='Truth')
plt.plot(x,y,'ro',markersize=4)
ax.set_xlim(-10, 10)
ax.set_ylim(-10, 10)
plt.show()

# %% [markdown]
# e) Plot the least squares estimate line through the scatter plot.

# %%
intercept = np.ones(np.shape(x)[0])
X = np.array([intercept, x, x**2]).T
beta_hat = np.linalg.inv(X.T @ X) @ X.T @ y

x_plot = np.linspace(-10,10,50)
y_est = beta_hat[0] + beta_hat[1] * x_plot + beta_hat[2] * x_plot**2
plt.plot(x_plot, y_est,'b--', lw=2, label='Estimate')
plt.plot(x_plot, true_beta[0] + true_beta[1] * x_plot + true_beta[2] * x_plot**2, lw=2, c='g', label='Truth')
plt.plot(x, y,'ro',markersize=4)
plt.legend()
plt.show()

# %% [markdown]
# f) How does the estimate of `beta` compare to the parameters we used to generate the data?

# %%
print(beta_hat)
print(true_beta)

# the beta estimates are pretty close; the first parameter is a little off, though.
# Out:
# [0.70626666 2.99561871 0.5091607 ]
# [1.  3.  0.5]

# %% [markdown]
# g) Let's repeat d) and f) a large number of times to see how close our estimates are on average and what that distribution looks like.

# %%
import numpy as np
import matplotlib.pyplot as plt

betas = []
true_beta = np.array([ 1, 3, 0.5 ])
for _ in range(10000):
    x = -1 + 2 * np.random.random(SAMPLE_SIZE)
    y = true_beta[0] + true_beta[1] * x + true_beta[2] * (x**2) + np.random.randn(SAMPLE_SIZE)
    intercept = np.ones(np.shape(x)[0])
    X = np.array([intercept, x]).T
    betas.append(np.linalg.inv(X.T @ X) @ X.T @ y)

plt.hist(np.array(betas)[:, 1], bins=100)
plt.axvline(x=true_beta[1], c='r', linestyle='dashed')
plt.show()

# it's a normal distribution!
